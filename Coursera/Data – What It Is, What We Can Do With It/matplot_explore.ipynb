# %% [markdown]
# # Early exploration of data shapes

# %%
import numpy as np 
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
# histogram data from the introductory statistics book: 
# https://openstax.org/books/introductory-statistics/pages/2-2-histograms-frequency-polygons-and-time-series-graphs
# list
semi_data = "60; 60.5; 61; 61; 61.5; 63.5; 63.5; 63.5; 64; 64; 64; 64; 64; 64; 64; 64.5; 64.5; 64.5; 64.5; 64.5; 64.5; 64.5; 64.5; 66; 66; 66; 66; 66; 66; 66; 66; 66; 66; 66.5; 66.5; 66.5; 66.5; 66.5; 66.5; 66.5; 66.5; 66.5; 66.5; 66.5; 67; 67; 67; 67; 67; 67; 67; 67; 67; 67; 67; 67; 67.5; 67.5; 67.5; 67.5; 67.5; 67.5; 67.5; 68; 68; 69; 69; 69; 69; 69; 69; 69; 69; 69; 69; 69.5; 69.5; 69.5; 69.5; 69.5;70; 70; 70; 70; 70; 70; 70.5; 70.5; 70.5; 71; 71; 71; 72; 72; 72; 72.5; 72.5; 73; 73.5; 74"
semi_data_list = semi_data.split("; ")
semi_data_list
pdata = pd.Series(semi_data.split("; "))
plt.hist(pdata, density=True, bins=8)
plt.axis([60,74,0,0.06])
# Out:
# (array([0.01469238, 0.04040404, 0.10651974, 0.0697888 , 0.05876951,
#         0.03305785, 0.02938476, 0.01101928]),
#  array([ 0.  ,  2.75,  5.5 ,  8.25, 11.  , 13.75, 16.5 , 19.25, 22.  ]),
#  <BarContainer object of 8 artists>)
